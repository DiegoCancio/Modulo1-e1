# %% [markdown]
# # Cargar librerias

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Carga del dataset
# Lea el dataset y conviertelo en un dataframe. Imprima el data frame una vez lo tenga

# %%
df = pd.read_csv(r"C:\Users\34699\OneDrive\Escritorio\bootcamp\Modulo1\Ejercico1\listas_musica.csv")
df.head(20)
# Out:
#           date  rank                     song  \
# 0   2021-11-06     1               Easy On Me
# 1   2021-11-06     2                     Stay
# 2   2021-11-06     3            Industry Baby
# 3   2021-11-06     4               Fancy Like
# 4   2021-11-06     5               Bad Habits
# 5   2021-11-06     6               Way 2 Sexy
# 6   2021-11-06     7                  Shivers
# 7   2021-11-06     8                 Good 4 U
# 8   2021-11-06     9             Need To Know
# 9   2021-11-06    10               Levitating
# 10  2021-11-06    11                  Essence
# 11  2021-11-06    12             Kiss Me More
# 12  2021-11-06    13               Heat Waves
# 13  2021-11-06    14                  Beggin'
# 14  2021-11-06    15  Cold Heart (PNAU Remix)
# 15  2021-11-06    16                You Right
# 16  2021-11-06    17          Save Your Tears
# 17  2021-11-06    18     If I Didn't Love You
# 18  2021-11-06    19                  Traitor
# ...

# %% [markdown]
# # Limpieza de datos

# %%
if df.isnull().any().any():
    print("Hay datos vacíos en el DataFrame.")
else:
    print("No hay datos vacíos en el DataFrame.")
# Out:
# Hay datos vacíos en el DataFrame.

# %%
df.fillna(0, inplace=True)
df.head(20)
# Out:
#           date  rank                     song  \
# 0   2021-11-06     1               Easy On Me
# 1   2021-11-06     2                     Stay
# 2   2021-11-06     3            Industry Baby
# 3   2021-11-06     4               Fancy Like
# 4   2021-11-06     5               Bad Habits
# 5   2021-11-06     6               Way 2 Sexy
# 6   2021-11-06     7                  Shivers
# 7   2021-11-06     8                 Good 4 U
# 8   2021-11-06     9             Need To Know
# 9   2021-11-06    10               Levitating
# 10  2021-11-06    11                  Essence
# 11  2021-11-06    12             Kiss Me More
# 12  2021-11-06    13               Heat Waves
# 13  2021-11-06    14                  Beggin'
# 14  2021-11-06    15  Cold Heart (PNAU Remix)
# 15  2021-11-06    16                You Right
# 16  2021-11-06    17          Save Your Tears
# 17  2021-11-06    18     If I Didn't Love You
# 18  2021-11-06    19                  Traitor
# ...

# %% [markdown]
# # Muestre el top 15 de canciones junto con su cantante

# %%
print(df.columns)
# Out:
# Index(['date', 'rank', 'song', 'artist', 'last-week', 'peak-rank',
#        'weeks-on-board'],
#       dtype='object')

# %%
df['song_artist'] = df['song'] + ' - ' + df['artist']
canciones = df['song_artist'].value_counts()
canciones.head(15)
# Out:
# song_artist
# Blinding Lights - The Weeknd                                     90
# Radioactive - Imagine Dragons                                    87
# Sail - AWOLNATION                                                79
# I'm Yours - Jason Mraz                                           76
# How Do I Live - LeAnn Rimes                                      69
# Party Rock Anthem - LMFAO Featuring Lauren Bennett & GoonRock    68
# Counting Stars - OneRepublic                                     68
# Foolish Games/You Were Meant For Me - Jewel                      65
# Rolling In The Deep - Adele                                      65
# Before He Cheats - Carrie Underwood                              64
# You And Me - Lifehouse                                           62
# I Hope - Gabby Barrett Featuring Charlie Puth                    62
# Ho Hey - The Lumineers                                           62
# Circles - Post Malone                                            61
# ...

# %%
df.value_counts(['song','artist']).head(15)
# Out:
# song                                 artist
# Blinding Lights                      The Weeknd                                   90
# Radioactive                          Imagine Dragons                              87
# Sail                                 AWOLNATION                                   79
# I'm Yours                            Jason Mraz                                   76
# How Do I Live                        LeAnn Rimes                                  69
# Counting Stars                       OneRepublic                                  68
# Party Rock Anthem                    LMFAO Featuring Lauren Bennett & GoonRock    68
# Rolling In The Deep                  Adele                                        65
# Foolish Games/You Were Meant For Me  Jewel                                        65
# Before He Cheats                     Carrie Underwood                             64
# ...

# %% [markdown]
# # Imprima algunos valores de ejemplos

# %%
df.tail(2)
# Out:
#               date  rank                                 song  \
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                  artist  last-week  peak-rank  weeks-on-board  \
# 330085   Billy Williams        0.0         99               1
# 330086  Frankie Vaughan        0.0        100               1
#
#                                               song_artist
# 330085  I'll Get By (As Long As I Have You) - Billy Wi...
# 330086                             Judy - Frankie Vaughan

# %% [markdown]
# # Calcule los 30 top artistas
#  puede usar funcion value_counts() y head()

# %%
df.value_counts(['artist','rank']).head(30)
# Out:
# artist               rank
# Mariah Carey         1       65
# The Beatles          1       54
# Madonna              2       41
# Mariah Carey         2       39
# Boyz II Men          1       34
# Madonna              1       32
# The Beatles          2       32
# Drake                1       31
# Whitney Houston      1       31
# Michael Jackson      1       30
# The Beatles          3       30
# The Black Eyed Peas  1       28
# Bee Gees             1       27
# Bruno Mars           3       26
# Adele                1       26
# Usher                2       26
# Taylor Swift         34      25
# Mariah Carey         4       25
# Taylor Swift         39      24
# Usher                3       24
# Madonna              4       24
# The Weeknd           4       23
# Madonna              11      23
# Boyz II Men          4       23
# Elton John           1       23
# Mariah Carey         7       23
# Usher                1       22
# Ed Sheeran           2       22
# ...

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['date', 'rank', 'song', 'artist', 'last-week', 'peak-rank',
#        'weeks-on-board', 'song_artist'],
#       dtype='object')

# %% [markdown]
# # Muestre el top 10 de los artistas, canciones y mejor posicion

# %%
df_ordenado = df.sort_values('rank')
df_ordenado = df_ordenado.drop_duplicates(subset='artist')

df_ordenado = df_ordenado[['rank','artist','song']]

df_ordenado.head(10)
# Out:
#         rank                                             artist  \
# 0          1                                              Adele
# 264887     1                                               Dawn
# 50300      1                       fun. Featuring Janelle Monae
# 265087     1                                    George Harrison
# 265487     1                     Smokey Robinson & The Miracles
# 265687     1  The Partridge Family Starring Shirley Jones Fe...
# 49700      1                             Gotye Featuring Kimbra
# 265987     1                                          Jackson 5
# 50400      1                                     Kelly Clarkson
# 50500      1                                         Katy Perry
#
#                                     song
# 0                             Easy On Me
# 264887                 Knock Three Times
# 50300                       We Are Young
# 265087     My Sweet Lord/Isn't It A Pity
# 265487              The Tears Of A Clown
# ...

# %% [markdown]
# # Artistas más reproduciodos por semanas

# %%
df['date'] = pd.to_datetime(df['date'])

df.set_index('date', inplace=False)

df.head(20)
# Out:
#          date  rank                     song  \
# 0  2021-11-06     1               Easy On Me
# 1  2021-11-06     2                     Stay
# 2  2021-11-06     3            Industry Baby
# 3  2021-11-06     4               Fancy Like
# 4  2021-11-06     5               Bad Habits
# 5  2021-11-06     6               Way 2 Sexy
# 6  2021-11-06     7                  Shivers
# 7  2021-11-06     8                 Good 4 U
# 8  2021-11-06     9             Need To Know
# 9  2021-11-06    10               Levitating
# 10 2021-11-06    11                  Essence
# 11 2021-11-06    12             Kiss Me More
# 12 2021-11-06    13               Heat Waves
# 13 2021-11-06    14                  Beggin'
# 14 2021-11-06    15  Cold Heart (PNAU Remix)
# 15 2021-11-06    16                You Right
# 16 2021-11-06    17          Save Your Tears
# 17 2021-11-06    18     If I Didn't Love You
# 18 2021-11-06    19                  Traitor
# 19 2021-11-06    20              My Universe
#
# ...

# %%
df.columns
# Out:
# Index(['rank', 'song', 'artist', 'last-week', 'peak-rank', 'weeks-on-board',
#        'song_artist'],
#       dtype='object')

# %% [markdown]
# # Encuentre los más y menos escuchados según un intervalo de tiempo

# %%
df['date'] = pd.to_datetime(df['date'])

df2 = df.set_index('date').resample("W")["artist"].agg(["first", "last"]).iloc[::-1]

df2.head()
# Out:
#                                     first                        last
# date
# 2021-11-07                          Adele  YoungBoy Never Broke Again
# 2021-10-31                          Adele             Priscilla Block
# 2021-10-24        Lil Nas X & Jack Harlow  YoungBoy Never Broke Again
# 2021-10-17  The Kid LAROI & Justin Bieber  YoungBoy Never Broke Again
# 2021-10-10                 Coldplay x BTS                  Kanye West
